# %% [markdown]
# <a href="https://colab.research.google.com/github/iasminqmoura/ia_2023/blob/main/Aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "name": ["Avery Bradley", "John Holland", "Jonas Jerebko", "Jordan Mickey", "Terry Rozier", "Jared Sullinger", "Evan Turner"],
    "team": ["Boston Celtics"] * 7,
    "number": [0, 30, 8, 99, 12, 7, 11],
    "position": ["PG", "SG", "PF", "PF", "PG", "C", "SG"],
    "age": [25, 27, 29, 21, 22, 99, 27]
}

# %%
print(data)
# Out:
# {'name': ['Avery Bradley', 'John Holland', 'Jonas Jerebko', 'Jordan Mickey', 'Terry Rozier', 'Jared Sullinger', 'Evan Turner'], 'team': ['Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics'], 'number': [0, 30, 8, 99, 12, 7, 11], 'position': ['PG', 'SG', 'PF', 'PF', 'PG', 'C', 'SG'], 'age': [25, 27, 29, 21, 22, 99, 27]}

# %%
df = pd.DataFrame(data = data)
df

# %%
df [['name', 'team']]

# %%
df.loc[0]['name']
# Out:
# 'Avery Bradley'

# %%
df = pd.read_csv('data.csv')
pd.options.display.max_rows = 60
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
#limpar linhas com célular vazias
new_df = df.dropna() #retorna um novo df e não altera o df original
#df.dropna(inplace = True) #altera df original

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB

# %%
new_df.drop(columns = "Calories", inplace = True)
new_df
# Out:
# <ipython-input-21-f8e1d7a8d4c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns = "Calories", inplace = True)
#      Duration  Pulse  Maxpulse
# 0          60    110       130
# 1          60    117       145
# 2          60    103       135
# 3          45    109       175
# 4          45    117       148
# ..        ...    ...       ...
# 164        60    105       140
# 165        60    110       145
# 166        60    115       145
# 167        75    120       150
# 168        75    125       150
#
# [164 rows x 3 columns]
